# %%
from collections import OrderedDict

import pandas as pd
import numpy as np

import blaze as bz

from bokeh.sampledata.us_states import data as states
from bokeh.plotting import figure
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.io import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0185d8ed-4034-4927-a415-9005198e9a7b">Loading BokehJS ...</span>
#     </div>

# %%
# https://catalog.data.gov/dataset/impaired-driving-death-rate-by-age-and-gender-2012-all-states-587fd
# impaired driving death rate by age and genter 2012
# Rate of deaths by age/gender (per 100,000 population) for people killed in
# crashes involving a driver with BAC =[HTML_REMOVED]0.08%, 2012 Source:
# Fatality Analysis Reporting System (FARS) Note: Blank cells indicate data are
# suppressed. Fatality rates based on fewer than 20 deaths are suppressed.
s1 = 'https://data.cdc.gov/api/views/ebbj-sh54/rows.csv?accessType=DOWNLOAD'
d = bz.data(s1)

# %% [markdown]
# The `data` interface automatically downloads and caches the `*.CSV` file to a temporary location on disk:
#   `bz.data('https://data.cdc.gov/api/views/ebbj-sh54/rows.csv?accessType=DOWNLOAD')`
#
# The interactive feature allows data exploration and blaze queries this file to print the data as the following functions `(head(), nrows, sort(), ...)` are executed.
#
# Q: When does the temporary file get cleaned up? Does blaze do this automatically?

# %%
d.head()
# Out:
#                   State  Ages 0-20  Ages 21-34  Ages 35+  All Ages  Male  \
# 0                 Maine        NaN         NaN       2.8       3.8   6.6
# 1              Kentucky        1.8         7.2       3.7       4.0   6.5
# 2             Louisiana        2.8         8.6       5.1       5.2   8.3
# 3               Florida        1.2         8.0       3.3       3.7   5.7
# 4            New Jersey        NaN         4.6       1.4       1.8   2.9
# 5  District of Columbia        NaN         NaN       NaN       NaN   NaN
# 6          North Dakota        NaN        15.3      12.0      11.3  17.4
# 7         New Hampshire        NaN         NaN       2.9       2.4   4.1
# 8             Minnesota        NaN         3.7       2.2       2.1   3.2
# 9        South Carolina        2.8        14.2       7.6       7.6  12.3
#
#    Female                                           Location
# 0     NaN     Maine\n(45.25422910300006, -68.98502586699993)
# 1     1.5  Kentucky\n(37.64597313300004, -84.77496771599994)
# 2     2.4  Louisiana\n(31.312663324000027, -92.4456775049...
# 3     1.7  Florida\n(28.932042722000062, -81.92895768899996)
# 4     0.9  New Jersey\n(40.130570807000026, -74.273687969...
# 5     NaN  District of Columbia\n(38.89037258400003, -77....
# 6     NaN  North Dakota\n(47.475318609000055, -100.118427...
# 7     NaN  New Hampshire\n(43.65595283500005, -71.5003569...
# 8     1.2  Minnesota\n(46.35564896600005, -94.79419983199...
# 9     3.2  South Carolina\n(33.99882216300006, -81.045365...

# %%
d.sort('Male', ascending=False)[['State', 'Male', 'Female', 'All Ages']].head(5)
# Out:
#              State  Male  Female  All Ages
# 6     North Dakota  17.4     NaN      11.3
# 49         Montana  14.9     4.0       9.4
# 9   South Carolina  12.3     3.2       7.6
# 42         Wyoming  11.3     NaN       7.1
# 17     Mississippi   9.8     2.7       6.1

# %%
d.sort('Female', ascending=False)[['State', 'Male', 'Female', 'All Ages']].head(5)
# Out:
#              State  Male  Female  All Ages
# 49         Montana  14.9     4.0       9.4
# 9   South Carolina  12.3     3.2       7.6
# 36      New Mexico   6.9     2.9       4.8
# 30         Alabama   8.4     2.9       5.5
# 17     Mississippi   9.8     2.7       6.1

# %%
d.sort('Ages 0-20', ascending=False)[['State', 'Ages 0-20', 'Male', 'Female', 'All Ages']].head(5)
# Out:
#              State  Ages 0-20  Male  Female  All Ages
# 9   South Carolina        2.8  12.3     3.2       7.6
# 2        Louisiana        2.8   8.3     2.4       5.2
# 30         Alabama        2.7   8.4     2.9       5.5
# 17     Mississippi        2.6   9.8     2.7       6.1
# 34          Kansas        2.3   6.0     NaN       3.4

# %%
d.Male.sum()
# Out:
# 300.99999999999994

# %%
d.Female.sum()
# Out:
# 58.2

# %%
d = bz.merge(d, ratio=d.Female/d.Male)

# %%
df = bz.compute(d)
df.head()
# Out:
#         State  Ages 0-20  Ages 21-34  Ages 35+  All Ages  Male  Female  \
# 0       Maine        NaN         NaN       2.8       3.8   6.6     NaN
# 1    Kentucky        1.8         7.2       3.7       4.0   6.5     1.5
# 2   Louisiana        2.8         8.6       5.1       5.2   8.3     2.4
# 3     Florida        1.2         8.0       3.3       3.7   5.7     1.7
# 4  New Jersey        NaN         4.6       1.4       1.8   2.9     0.9
#
#                                             Location     ratio
# 0     Maine\n(45.25422910300006, -68.98502586699993)       NaN
# 1  Kentucky\n(37.64597313300004, -84.77496771599994)  0.230769
# 2  Louisiana\n(31.312663324000027, -92.4456775049...  0.289157
# 3  Florida\n(28.932042722000062, -81.92895768899996)  0.298246
# 4  New Jersey\n(40.130570807000026, -74.273687969...  0.310345

# %%
name_abv = {val['name']: abv for abv, val in states.items()}

# state: (lat, long)
# (lat, long) = [(float(i[1].split(',')[0][1:]), float(i[1].split(',')[1][:-1])) for i in df.Location.str.split('\n')]
us = df[df['State'] == 'United States']
df = df[df['State'] != 'United States']
df['lons'] = [states[name_abv[name]]["lons"] for name in df.State]
df['lats'] = [states[name_abv[name]]["lats"] for name in df.State]

colors = ["#F1EEF6", "#D4B9DA", "#C994C7", "#DF65B0", "#DD1C77"]
c_vals = np.linspace(df['All Ages'].min(), df['All Ages'].max(), 5)

df['color'] = "#FFFFFF"

for ix, r in df.iterrows():
    if not np.isnan(r['All Ages']):
        df.loc[ix, 'color'] = colors[np.argmin(r['All Ages'] > c_vals)]

# %%
c_df = df[~df['State'].isin(['Alaska', 'Hawaii'])]
nc_df = df[df['State'].isin(['Alaska', 'Hawaii'])]

# %%
c_source = ColumnDataSource(data=c_df)
nc_source = ColumnDataSource(data=nc_df)

# %%
TOOLS = "pan,wheel_zoom,box_zoom,reset,resize,hover"
p = figure(title="US Impaired Driving Death Rate 2012", toolbar_location="left",
           plot_width=1000, plot_height=600, tools=TOOLS)

# %%
p.patches("lons", "lats", source=c_source, fill_color="color", fill_alpha=0.7,
          line_color="#884444", line_width=2, line_alpha=0.3)

hover = p.select(dict(type=HoverTool))
hover.tooltips = OrderedDict([
    ("State", "@State"),
    ("All Ages", "@{All Ages}"),
    ("F/M Ratio", "@ratio")
])

show(p)
# Out:
#     <div class="plotdiv" id="d5255be1-740a-4440-a5ff-d017e84d9e65"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d5255be1-740a-4440-a5ff-d017e84d9e65");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd5255be1-740a-4440-a5ff-d017e84d9e65' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"32653713-b9c3-45c7-95ef-621a68f64c39":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"},"ticker":{"id":"121e2aa6-93f0-4905-ae57-773c6db45872","type":"BasicTicker"}},"id":"366eb23e-61ae-437b-8844-d8166ebc0c58","type":"Grid"},{"attributes":{"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"}},"id":"01ffdb7b-0b1c-475d-89cf-f40f81090b89","type":"ResetTool"},{"attributes":{},"id":"d5b489e4-3fb6-422b-a247-adc227c8f231","type":"ToolEvents"},{"attributes":{},"id":"c6b7b0cf-e73b-42e9-b0fa-a8984858f095","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"c6b7b0cf-e73b-42e9-b0fa-a8984858f095","type":"BasicTickFormatter"},"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"},"ticker":{"id":"121e2aa6-93f0-4905-ae57-773c6db45872","type":"BasicTicker"}},"id":"4dea4133-78af-48ff-9aaf-bb20112ba43d","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"field":"color"},"line_alpha":{"value":0.3},"line_color":{"value":"#884444"},"line_width":{"value":2},"xs":{"field":"lons"},"ys":{"field":"lats"}},"id":"a1ad81fe-8da4-415c-9a09-6a735dba86d2","type":"Patches"},{"attributes":{"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"}},"id":"bcab47a3-6c7c-4d2b-85a8-9c524fbe317f","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"a8ba31a9-9752-4b73-9245-85937361f777","type":"BoxAnnotation"},"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"}},"id":"1fecdb17-f9e1-467b-8028-c12ec27a008d","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a8ba31a9-9752-4b73-9245-85937361f777","type":"BoxAnnotation"},{"attributes":{"callback":null,"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"},"tooltips":[["State","@State"],["All Ages","@{All Ages}"],["F/M Ratio","@ratio"]]},"id":"7d4a2c1c-690d-4083-8474-506c4635458e","type":"HoverTool"},{"attributes":{},"id":"121e2aa6-93f0-4905-ae57-773c6db45872","type":"BasicTicker"},{"attributes":{"callback":null},"id":"daf617d0-9664-4955-b35a-2b2057e40bfe","type":"DataRange1d"},{"attributes":{"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"}},"id":"57e4b5d5-9a91-48d5-b0b8-fcefbf5a5ab4","type":"PanTool"},{"attributes":{},"id":"202b065a-8d04-4d5b-a13f-07a1061c0a8b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"},"ticker":{"id":"b4b5789a-168d-479b-86fe-d703b65b5534","type":"BasicTicker"}},"id":"88191e84-d66c-44a1-a32d-02f6ea81e76a","type":"Grid"},{"attributes":{"callback":null,"column_names":["Ages 0-20","Location","All Ages","color","Male","lons","ratio","index","Ages 21-34","Ages 35+","Female","State","lats"],"data":{"Ages 0-20":["NaN",1.8,2.8,1.2,"NaN","NaN","NaN","NaN","NaN",2.8,"NaN",1.6,1.2,0.6,1.2,2.1,2.6,0.7,"NaN","NaN",1.7,"NaN","NaN","NaN","NaN",1.1,1.6,2.7,"NaN",1.2,"NaN",2.3,0.9,"NaN","NaN",1.9,"NaN",1.4,1.6,"NaN","NaN","NaN",1.6,1.0,"NaN","NaN","NaN","NaN","NaN"],"Ages 21-34":["NaN",7.2,8.6,8.0,4.6,"NaN",15.3,"NaN",3.7,14.2,5.2,6.5,4.5,3.3,6.8,10.0,12.0,6.0,"NaN",10.5,8.0,"NaN",10.5,6.5,3.3,6.8,8.0,10.3,"NaN",7.2,12.9,6.0,4.5,9.1,"NaN",9.5,8.7,7.2,6.9,17.3,5.9,4.0,5.8,5.8,5.9,"NaN",21.4,4.6,5.6],"Ages 35+":[2.8,3.7,5.1,3.3,1.4,"NaN",12.0,2.9,2.2,7.6,1.8,3.5,2.6,1.7,3.3,4.7,5.7,2.1,"NaN",4.3,4.0,"NaN",5.8,3.5,1.7,2.0,4.9,5.0,1.9,3.5,4.4,3.0,1.8,4.5,"NaN",4.4,2.7,2.8,3.3,"NaN",2.9,2.0,2.2,3.1,2.1,4.0,7.2,3.2,2.0],"All Ages":[3.8,4.0,5.2,3.7,1.8,"NaN",11.3,2.4,2.1,7.6,2.2,3.6,2.5,1.7,3.5,4.9,6.1,2.5,2.3 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>

# %%
p2 = figure(title="US Impaired Driving Death Rate 2012", toolbar_location="left",
            plot_width=1000, plot_height=500, tools=TOOLS)
p2.patches("lons", "lats", source=nc_source, fill_color="color", fill_alpha=0.7,
          line_color="#884444", line_width=2, line_alpha=0.3)
hover = p2.select(dict(type=HoverTool))
hover.tooltips = OrderedDict([
    ("State", "@State"),
    ("All Ages", "@{All Ages}"),
    ("F/M Ratio", "@ratio")
])

show(p2)
# Out:
#     <div class="plotdiv" id="1bc346da-11fd-4dff-8380-da445e62061b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1bc346da-11fd-4dff-8380-da445e62061b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1bc346da-11fd-4dff-8380-da445e62061b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"18cec263-9389-4765-8592-d3c61138cb83":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"},"ticker":{"id":"121e2aa6-93f0-4905-ae57-773c6db45872","type":"BasicTicker"}},"id":"366eb23e-61ae-437b-8844-d8166ebc0c58","type":"Grid"},{"attributes":{"plot":{"id":"fc7c6912-d225-4a5a-a912-527c8ba70a98","subtype":"Figure","type":"Plot"}},"id":"03de8b7a-79a7-4c45-9853-419ef1a57ae0","type":"ResizeTool"},{"attributes":{"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"}},"id":"01ffdb7b-0b1c-475d-89cf-f40f81090b89","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"xs":{"field":"lons"},"ys":{"field":"lats"}},"id":"7a33658b-d631-491c-b732-0521336e6b1c","type":"Patches"},{"attributes":{},"id":"d8335a08-0664-4853-9913-f0c63c5c8ec1","type":"ToolEvents"},{"attributes":{"formatter":{"id":"c6b7b0cf-e73b-42e9-b0fa-a8984858f095","type":"BasicTickFormatter"},"plot":{"id":"794287f7-854e-4fa7-b070-2f764e2fa74e","subtype":"Figure","type":"Plot"},"ticker":{"id":"121e2aa6-93f0-4905-ae57-773c6db45872","type":"BasicTicker"}},"id":"4dea4133-78af-48ff-9aaf-bb20112ba43d","type":"LinearAxis"},{"attributes":{"overlay":{"id":"f165753d-3abe-489e-87fe-61f5fb3fe7cf","type":"BoxAnnotation"},"plot":{"id":"fc7c6912-d225-4a5a-a912-527c8ba70a98","subtype":"Figure","type":"Plot"}},"id":"328f519e-4fe0-45ce-973a-e5542a6a45f9","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"96d4b37e-05ab-49e3-9fb9-92936a7716a7","type":"DataRange1d"},{"attributes":{"formatter":{"id":"5e71db3e-11b3-4b6e-8443-56eb6a36fefc","type":"BasicTickFormatter"},"plot":{"id":"fc7c6912-d225-4a5a-a912-527c8ba70a98","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c1f69d1-33fa-461b-a5dd-b102a2deee82","type":"BasicTicker"}},"id":"5ebe214b-f7bd-4774-ba58-982389b4e8bb","type":"LinearAxis"},{"attributes":{},"id":"c2a03275-98fb-4719-bed0-5e8f44101b27","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"47b25fda-3569-419a-86e4-afd8022ac2e3","type":"DataRange1d"},{"attributes":{"plot":{"id":"fc7c6912-d225-4a5a-a912-527c8ba70a98","subtype":"Figure","type":"Plot"},"ticker":{"id":"be146dca-206e-423d-97d8-9a430a129a45","type":"BasicTicker"}},"id":"6dc6ddbe-0570-4f89-a4ae-9ac58bc3b6c0","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"fc7c6912-d225-4a5a-a912-527c8ba70a98","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c1f69d1-33fa-461b-a5dd-b102a2deee82","type":"BasicTicker"}},"id":"e55ef458-5679-4117-89f2-a2b5a7db2584","type":"Grid"},{"attributes":{"callback":null,"column_names":["Ages 0-20","Location","All Ages","color","Male","lons","ratio","index","Ages 21-34","Ages 35+","Female","State","lats"],"data":{"Ages 0-20":["NaN","NaN"],"Ages 21-34":["NaN","NaN"],"Ages 35+":[3.2,"NaN"],"All Ages":[3.8,"NaN"],"Female":["NaN","NaN"],"Location":["Hawaii\n(21.30485232600006, -157.85774798099996)","Alaska\n(64.84507799500005, -147.72205958799998)"],"Male":[5.7,"NaN"],"State":["Hawaii","Alaska"],"color":["#C994C7","#FFFFFF"],"index":[19,23],"lats":[[21.24683,21.23619,21.20918,21.20949,21.21385,21.22092,21.21439,21.20963,21.20639,21.20109,21.20085,21.20907,21.21801,21.22494,21.24323,21.24994,21.24784,21.24754,21.24784,21.25,21.25464,21.25654,21.2533,21.25144,21.25,21.25,21.24964,21.24924,21.24834,21.24287,21.24098,21.24239,21.25174,21.26744,21.34594,21.35353,21.35903,21.37563,21.40323,21.41221,21.42169,21.43792,21.44963,21.47015,21.47935,21.49841,21.53915,21.56429,21.59667,21.61728,21.62784,21.63447,21.642,21.65856,21.65152,21.66391,21.67081,21.67911,21.6921,21.71269,21.73009,21.74308,21.76159,21.74818,21.73289,21.72306,21.71208,21.69619,21.67413,21.64272,21.61622,21.6071,21.59775,21.5931,21.5852,21.56541,21.55819,21.54881,21.54111,21.53799,21.51241,21.52081,21.50185,21.4929,21.48421,21.46719,21.4455,21.43612,21.4228 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[16]</strong>&gt;</code></p>
